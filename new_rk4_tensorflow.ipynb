# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.15.0

# %%
# !pip install tensorflow==1.4
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==1.4 (from versions: 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.0.post1, 2.15.1, 2.16.0rc0, 2.16.1)
# ERROR: No matching distribution found for tensorflow==1.4

# %%
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split

class RungeKuttaNN:
    def __init__(self, timestep, t_init, t_end):
        self.timestep = timestep
        self.t_init = t_init
        self.t_end = t_end
        self.n_oppar = 0
        self.n_var = 0
        self.n_inputs = 0
        self.n_hidden1 = 20
        self.n_hidden2 = 20
        self.n_batches = 10
        self.bsize = 0
        self.train_epochs = 900
        self.dstep = 50
        self.lr = 0.001
        self.test_ratio = 0.1
        self.bound = 0.000005
        self.test_prop = 0.2
        self.w1 = []
        self.w2 = []
        self.w3 = []
        self.b1 = []
        self.b2 = []
        self.b3 = []
        self.tf_w1 = []
        self.tf_w2 = []
        self.tf_w3 = []
        self.tf_b1 = []
        self.tf_b2 = []
        self.tf_b3 = []
        self.input_x = []
        self.input_y = []
        self.output = []
        self.data = []

    def __enter__(self):
        return self

    def __exit__(self, exception_type, exception_value, traceback):
        tf.compat.v1.reset_default_graph()

    def _tf_act_fun(self, y):
        return tf.nn.relu(y)

    def _tf_predict_dy(self, y, x):
        stack = tf.concat(values=[y, x], axis=1)
        layer_1 = tf.matmul(stack, self.tf_w1) + self.tf_b1
        layer_1 = self._tf_act_fun(layer_1)
        # layer_2 = tf.matmul(layer_1, self.tf_w2) + self.tf_b2
        # layer_2 = self._tf_act_fun(layer_2)
        out = tf.matmul(layer_1, self.tf_w3) + self.tf_b3
        return out

    def _tf_forward_pass(self, y, x):
        dt = self.timestep
        k1 = dt * self._tf_predict_dy(y, x)
        k2 = dt * self._tf_predict_dy(y + k1 / 2, x)
        k3 = dt * self._tf_predict_dy(y + k2 / 2, x)
        k4 = dt * self._tf_predict_dy(y + k3, x)
        out = y + (k1 + 2*k2 + 2*k3 + k4) / 6
        return out

    def _act_fun(self, y):
        """Activation function for prediction
        So far only using sigmoid, tanh and ReLU
        :param y: variable vector to be fed into activation function
        :return: f(y) where f is the activation function
        """
        #return np.tanh(y)
        # return 1.0/(1 + np.exp(-y))
        return np.fmax(0.0, y)

    def _predict_dy(self, y, x):
        """Predict F(y,x) as in y' = dy/dt = F(y,x)

        :param y: variable vector
        :param x: operating parameters
        :return: F(y,x) according to the trained neural network
        """
        z = np.hstack((y, x))
        layer_1 = z @ self.w1 + self.b1
        layer_1 = self._act_fun(layer_1)
        # layer_2 = layer_1 @ self.w2 + self.b2
        # layer_2 = self._act_fun(layer_2)
        out = layer_1 @ self.w3 + self.b3
        return out

    def predict(self, y, x):
        """Forward pass along the RKNN or prediction y(t) -> y(t+1)

        :param y: variable vector at time step t ( or y(t) )
        :param x: operating parameters at time step t
        :return: variable vector at time step t+1 ( or y(t+1) )
        """
        dt = self.timestep
        k1 = dt * self._predict_dy(y, x)
        k2 = dt * self._predict_dy(y + k1 / 2, x)
        k3 = dt * self._predict_dy(y + k2 / 2, x)
        k4 = dt * self._predict_dy(y + k3, x)
        out = y + (k1 + 2 * k2 + 2 * k3 + k4) / 6
        return out

    def predict_from_samples(self, y, x, num_it):
        """Multiple predict's: long time prediction

        :param y: variable vector at the FIRST time step
        :param x: operating parameter at first time step
        :param num_it: number of iteration desired to compute y_1, y_2 .. y_{num_it}
        :return: vector containing future time steps of length num_it
        """
        current_y = y
        current_x = x[0]
        pred_list = y
        for it in range(num_it - 1):
            pred_var = self.predict(current_y, current_x)
            pred_list = np.vstack((pred_list, pred_var))
            current_y = pred_var
            current_x = x[it+1]
        return pred_list

    def start_train(self, data_y, data_x, output_y):
        assert (data_y.shape == output_y.shape), \
            "Input variable shape (%f,%f) does not match output dimension (%f,%f)" \
            %(data_y.shape[0], data_y.shape[1], output_y.shape[0], output_y.shape[1])

        assert (data_y.shape[0] == data_x.shape[0]), \
            "Number of variable snapshots %f does not match number of parameter snapshots %f" \
            %(data_y.shape[0], data_x.shape[0])

        assert (self.test_ratio <= 1.0), "Test ratio %f should be smaller than 1" % self.test_ratio

        if data_y.ndim == 1:
            data_y = data_y.reshape((data_y.shape[0], 1))
        if data_x.ndim == 1:
            data_x = data_x.reshape((data_x.shape[0], 1))

        self.n_var = data_y.shape[1]
        self.n_oppar = data_x.shape[1]
        self.n_inputs = self.n_var + self.n_oppar

        self.output = output_y
        self.input_y = data_y
        self.input_x = data_x

        n_samples = self.input_y.shape[0]
        self.data = np.hstack((data_y, data_x))

        joint_input = np.hstack((self.input_y, self.input_x))

        # print("var-oppar-inputs", self.n_var, self.n_oppar, self.n_inputs)
        print("output",self.output)
        # print("input_y",self.input_y)
        # print("input_x",self.input_x)
        # print("data",self.data)
        print("n", n_samples)
        print("data",joint_input)

        train_input, test_input, \
        train_output, test_output = train_test_split(joint_input, self.output,
                                                     test_size=int(n_samples * self.test_ratio), random_state=42)

        n_train = train_input.shape[0]
        test_y = test_input[:, :self.n_var]
        test_x = test_input[:, self.n_var:]

        if self.bsize != 0:
            self.n_batches = int(n_train / self.bsize)
        else:
            self.bsize = int(n_train / self.n_batches)

        leftover = n_train - self.n_batches * self.bsize

        tf.compat.v1.disable_v2_behavior()

        x = tf.compat.v1.placeholder("float", [None, self.n_oppar], name="OperatingParameters")
        y = tf.compat.v1.placeholder("float", [None, self.n_var], name="ODEInputVariable")
        z = tf.compat.v1.placeholder("float", [None, self.n_var], name="ODEOutputVariable")

        self.tf_w1 = tf.Variable(tf.keras.initializers.glorot_normal()((self.n_inputs, self.n_hidden1)), name="w1")
        # self.tf_w2 = tf.Variable(tf.keras.initializers.glorot_normal()((self.n_hidden1, self.n_hidden2)), name="w2")
        self.tf_w3 = tf.Variable(tf.keras.initializers.glorot_normal()((self.n_hidden1, self.n_var)), name="w3")

        self.tf_b1 = tf.Variable(tf.zeros([self.n_hidden1]), "b1")
        # self.tf_b2 = tf.Variable(tf.zeros([self.n_hidden2]), "b2")
        self.tf_b3 = tf.Variable(tf.zeros([self.n_var]), "b3")

        pred = self._tf_forward_pass(y, x)

        pow_diff = tf.pow(pred - z, 2)
        loss = tf.reduce_sum(pow_diff)

        optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=self.lr).minimize(loss)

        epoch = 0
        train_loss = 50

        with tf.compat.v1.Session() as sess:
            sess.run(tf.compat.v1.global_variables_initializer())
            while train_loss > self.bound and epoch < self.train_epochs:
                epoch += 1
                rand_index = np.random.permutation(n_train)
                train_y = train_input[rand_index, :self.n_var].reshape((n_train, self.n_var))
                train_x = train_input[rand_index, self.n_var:].reshape((n_train, self.n_oppar))
                train_out = train_output[rand_index].reshape((n_train, self.n_var))
                for i in range(self.n_batches):
                    data_in_y = train_y[i * self.bsize:(i + 1) * self.bsize]
                    data_in_x = train_x[i * self.bsize:(i + 1) * self.bsize]
                    data_out = train_out[i * self.bsize:(i + 1) * self.bsize]
                    values = {y: data_in_y,
                              x: data_in_x,
                              z: data_out}
                    sess.run(optimizer, feed_dict=values)

                if leftover != 0:
                    data_in_y = train_y[-leftover:]
                    data_in_x = train_x[-leftover:]
                    data_out = train_output[-leftover:]
                    values = {y: data_in_y,
                              x: data_in_x,
                              z: data_out}
                    sess.run(optimizer, feed_dict=values)

                if epoch % self.dstep == 0:
                    values = {y: test_y.reshape((test_y.shape[0], self.n_var)),
                              x: test_x.reshape((test_x.shape[0], self.n_oppar)),
                              z: test_output.reshape((test_output.shape[0], self.n_var))}
                    test_loss = sess.run(loss, feed_dict=values)
                    print('Test Loss at step %s: \t%s' % (epoch, test_loss))

                    values = {y: train_y.reshape((train_y.shape[0], self.n_var)),
                              x: train_x.reshape((train_x.shape[0], self.n_oppar)),
                              z: train_out.reshape((train_out.shape[0], self.n_var))}
                    train_loss = sess.run(loss, feed_dict=values)
                    print('Train Loss at step %s: \t%s' % (epoch, train_loss))

                self.w1, self.w2, self.w3, self.b1, self.b2, self.b3 = sess.run([self.tf_w1, self.tf_w2, self.tf_w3,
                                                                                 self.tf_b1, self.tf_b2, self.tf_b3])

# %%
import numpy as np

def ode_solution(t):
    """Sets 2D dynamical system
    """
    '''
    y1 = 10*np.cos(t*2*np.pi/100).reshape((t.shape[0],1))
    y2 = 3*np.sin(t*2*np.pi/100).reshape((t.shape[0],1))
    joint = np.hstack((y1,y2))
    '''
    y1 = (2*(np.cos(t) + t*np.sin(t))).reshape((t.shape[0],1))
    y2 = (2*(np.sin(t) - t*np.cos(t))).reshape((t.shape[0],1))
    joint = np.hstack((y1, y2))
    return joint


def set_data(timestep, t_init, t_end):
    t = np.arange(t_init, t_end, timestep)
    # Obtain ODE sol
    data = ode_solution(t)
    # Normalise
    mean = np.mean(data)
    data -= mean
    std = np.std(data)
    data /= std
    return data, mean, std

# %%
from matplotlib import pyplot as plt

# def main():
"""Approximates solution of ODE's with RK NN
"""
# Time step parameters
timestep = 0.01
t_init = 0
t_end = 100
num_it = int((t_end-t_init)/timestep)

## Initialise neural network and set parameters
rk = RungeKuttaNN(timestep, t_init, t_end)
# Number of batches
rk.n_batches = 10
# Number of training epochs
rk.train_epochs = 7000
# Learning rate
rk.lr = 1e-3
# Error target
rk.bound = 5e-8
# Number of neurons in the first layer
rk.n_hidden1 = 10
# rk.n_hidden2 = 20
#TODO: Parameters that can change : learning rate, #training epochs and number of hidden neurons
#TODO: Add dimensionality reduction techniques for big data
# Obtain experimental data and set main quantities
data, mean, std = set_data(timestep, t_init, t_end)
print("data", data)
n_samples = data.shape[0]
n_timesteps = n_samples-1
input_var = data[:n_timesteps]
print("input_var:", input_var, input_var.shape)
input_oppar = np.zeros((n_samples,1))   # Trivial parameter in this example
print("input_oppar:", input_oppar, input_oppar.shape)
output_var = data[1:]
print("output_var:", output_var, output_var.shape)
print(data[0], data[0].shape)
# Out:
# data [[ 0.02885859  0.0043653 ]
#  [ 0.02885982  0.00436531]
#  [ 0.02886349  0.00436536]
#  ...
#  [-1.27755604 -2.0819935 ]
#  [-1.25675693 -2.09491688]
#  [-1.23582753 -2.10763288]]
# input_var: [[ 0.02885859  0.0043653 ]
#  [ 0.02885982  0.00436531]
#  [ 0.02886349  0.00436536]
#  ...
#  [-1.29822281 -2.06886411]
#  [-1.27755604 -2.0819935 ]
#  [-1.25675693 -2.09491688]] (9999, 2)
# input_oppar: [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]] (10000, 1)
# output_var: [[ 0.02885982  0.00436531]
#  [ 0.02886349  0.00436536]
#  [ 0.02886961  0.00436552]
#  ...
#  [-1.27755604 -2.0819935 ]
#  [-1.25675693 -2.09491688]
#  [-1.23582753 -2.10763288]] (9999, 2)
# [0.02885859 0.0043653 ] (2,)

# %%
# Start training
rk.start_train(input_var, input_oppar[:n_timesteps], output_var)

time_vals = np.arange(t_init, t_end, timestep)
pred = rk.predict_from_samples(y=data[0], x=input_oppar, num_it=num_it)

#TODO: Optional- denormalise prediction and original data with mean and std

# Plots
fig = plt.figure(figsize=(15, 5))

ax = fig.add_subplot(131)
plt.plot(data[:,0], data[:,1], label="Real Value")
plt.plot(pred[:,0], pred[:,1], label="Prediction")
plt.title(r"ODE solution $y' = F(x,y)$")
plt.xlabel(r"$y_1$")
plt.ylabel(r"$y_2$")
plt.legend()

ax = fig.add_subplot(132)
plt.plot(time_vals, data[:, 0], label="Real Value")
plt.plot(time_vals, pred[:, 0], label="Prediction")
plt.title(r"ODE solution $y_1$")
plt.xlabel(r"$t$")
plt.ylabel(r"$y_1$")
plt.legend()

ax = fig.add_subplot(133)
plt.plot(time_vals, data[:, 1], label="Real Value")
plt.plot(time_vals, pred[:, 1], label="Prediction")
plt.title(r"ODE solution $y_2$")
plt.xlabel(r"$t$")
plt.ylabel(r"$y_2$")
plt.legend()

plt.show()


# if __name__ == '__main__':
#     main()
# Out:
# output [[ 0.02885982  0.00436531]
#  [ 0.02886349  0.00436536]
#  [ 0.02886961  0.00436552]
#  ...
#  [-1.27755604 -2.0819935 ]
#  [-1.25675693 -2.09491688]
#  [-1.23582753 -2.10763288]]
# n 9999
# data [[ 0.02885859  0.0043653   0.        ]
#  [ 0.02885982  0.00436531  0.        ]
#  [ 0.02886349  0.00436536  0.        ]
#  ...
#  [-1.29822281 -2.06886411  0.        ]
#  [-1.27755604 -2.0819935   0.        ]
#  [-1.25675693 -2.09491688  0.        ]]
# Test Loss at step 50: 	0.0073294225
# Train Loss at step 50: 	0.065879986
# Test Loss at step 100: 	0.0020694998
# Train Loss at step 100: 	0.018553717
# Test Loss at step 150: 	0.0015677628
# Train Loss at step 150: 	0.013822196
# Test Loss at step 200: 	0.0010770595
# Train Loss at step 200: 	0.009190948
# Test Loss at step 250: 	0.00031766813
# Train Loss at step 250: 	0.0026451207
# Test Loss at step 300: 	9.018577e-05
# Train Loss at step 300: 	0.0007487305
# Test Loss at step 350: 	3.2872496e-05
# Train Loss at step 350: 	0.0002729931
# Test Loss at step 400: 	1.920935e-05
# Train Loss at step 400: 	0.00015886412
# Test Loss at step 450: 	1.559528e-05
# Train Loss at step 450: 	0.0001305207
# Test Loss at step 500: 	1.37897305e-05
# Train Loss at step 500: 	0.00011681671
# Test Loss at step 550: 	1.2814803e-05
# Train Loss at step 550: 	0.000108753986
# Test Loss at step 600: 	1.2233219e-05
# Train Loss at step 600: 	0.00010437113
# Test Loss at step 650: 	1.192351e-05
# Train Loss at step 650: 	0.00010201215
# Test Loss at step 700: 	1.1744413e-05
# Train Loss at step 700: 	0.000100730256
# Test Loss at step 750: 	1.1591328e-05
# Train Loss at step 750: 	9.992901e-05
# Test Loss at step 800: 	1.1622934e-05
# Train Loss at step 800: 	9.9820834e-05
# Test Loss at step 850: 	1.1392055e-05
# Train Loss at step 850: 	9.8742894e-05
# Test Loss at step 900: 	1.1293163e-05
# Train Loss at step 900: 	9.8420714e-05
# Test Loss at step 950: 	1.1271227e-05
# Train Loss at step 950: 	9.76482e-05
# Test Loss at step 1000: 	1.1106773e-05
# Train Loss at step 1000: 	9.6933996e-05
# Test Loss at step 1050: 	1.0941298e-05
# Train Loss at step 1050: 	9.50904e-05
# Test Loss at step 1100: 	1.0828643e-05
# Train Loss at step 1100: 	9.420978e-05
# Test Loss at step 1150: 	1.0846148e-05
# Train Loss at step 1150: 	9.480705e-05
# Test Loss at step 1200: 	1.0571123e-05
# Train Loss at step 1200: 	9.2567825e-05
# Test Loss at step 1250: 	1.04514265e-05
# Train Loss at step 1250: 	9.094871e-05
# Test Loss at step 1300: 	1.036569e-05
# Train Loss at step 1300: 	8.950065e-05
# Test Loss at step 1350: 	1.0446438e-05
# Train Loss at step 1350: 	9.007382e-05
# Test Loss at step 1400: 	1.0412162e-05
# Train Loss at step 1400: 	8.9647256e-05
# Test Loss at step 1450: 	1.025199e-05
# Train Loss at step 1450: 	8.901045e-05
# Test Loss at step 1500: 	9.973121e-06
# Train Loss at step 1500: 	8.644075e-05
# Test Loss at step 1550: 	1.0068786e-05
# Train Loss at step 1550: 	8.682692e-05
# Test Loss at step 1600: 	9.952374e-06
# Train Loss at step 1600: 	8.53527e-05
# Test Loss at step 1650: 	9.914744e-06
# Train Loss at step 1650: 	8.456253e-05
# Test Loss at step 1700: 	9.776118e-06
# Train Loss at step 1700: 	8.407481e-05
# Test Loss at step 1750: 	9.608427e-06
# Train Loss at step 1750: 	8.279888e-05
# Test Loss at step 1800: 	9.481607e-06
# Train Loss at step 1800: 	8.16619e-05
# Test Loss at step 1850: 	9.288259e-06
# Train Loss at step 1850: 	8.015803e-05
# Test Loss at step 1900: 	9.0885505e-06
# Train Loss at step 1900: 	7.906921e-05
# Test Loss at step 1950: 	9.203026e-06
# Train Loss at step 1950: 	7.930085e-05
# Test Loss at step 2000: 	9.019135e-06
# Train Loss at step 2000: 	7.7969795e-05
# Test Loss at step 2050: 	8.624987e-06
# Train Loss at step 2050: 	7.472034e-05
# Test Loss at step 2100: 	8.68144e-06
# Train Loss at step 2100: 	7.4636424e-05
# Test Loss at step 2150: 	8.357556e-06
# Train Loss at step 2150: 	7.253678e-05
# Test Loss at step 2200: 	8.210661e-06
# Train Loss at step 2200: 	7.1058035e-05
# Test Loss at step 2250: 	8.2776405e-06
# Train Loss at step 2250: 	7.0810194e-05
# Test Loss at step 2300: 	8.246371e-06
# Train Loss at step 2300: 	6.961459e-05
# Test Loss at step 2350: 	8.095353e-06
# Train Loss at step 2350: 	6.842943e-05
# Test Loss at step 2400: 	8.05003e-06
# Train Loss at step 2400: 	6.887775e-05
# Test Loss at step 2450: 	8.064896e-06
# Train Loss at step 2450: 	6.823432e-05
# Test Loss at step 2500: 	8.202751e-06
# Train Loss at step 2500: 	6.846206e-05
# Test Loss at step 2550: 	8.095735e-06
# Train Loss at step 2550: 	6.730165e-05
# Test Loss at step 2600: 	8.155844e-06
# Train Loss at step 2600: 	6.826261e-05
# Test Loss at step 2650: 	8.160828e-06
# Train Loss at step 2650: 	6.767659e-05
# Test Loss at step 2700: 	8.179846e-06
# Train Loss at step 2700: 	6.714686e-05
# Test Loss at step 2750: 	8.201948e-06
# Train Loss at step 2750: 	6.732135e-05
# Test Loss at step 2800: 	8.155775e-06
# Train Loss at step 2800: 	6.685779e-05
# Test Loss at step 2850: 	8.050522e-06
# Train Loss at step 2850: 	6.645812e-05
# Test Loss at step 2900: 	8.139037e-06
# Train Loss at step 2900: 	6.6800385e-05
# Test Loss at step 2950: 	8.098683e-06
# Train Loss at step 2950: 	6.7268964e-05
# Test Loss at step 3000: 	8.213342e-06
# Train Loss at step 3000: 	6.7227316e-05
# Test Loss at step 3050: 	8.183388e-06
# Train Loss at step 3050: 	6.7403496e-05
# Test Loss at step 3100: 	8.226195e-06
# Train Loss at step 3100: 	6.773539e-05
# Test Loss at step 3150: 	8.208239e-06
# Train Loss at step 3150: 	6.846321e-05
# Test Loss at step 3200: 	8.113231e-06
# Train Loss at step 3200: 	6.777838e-05
# Test Loss at step 3250: 	8.267762e-06
# Train Loss at step 3250: 	6.629317e-05
# Test Loss at step 3300: 	8.295317e-06
# Train Loss at step 3300: 	6.651573e-05
# Test Loss at step 3350: 	8.050212e-06
# Train Loss at step 3350: 	6.59872e-05
# Test Loss at step 3400: 	8.048375e-06
# Train Loss at step 3400: 	6.576099e-05
# Test Loss at step 3450: 	8.144634e-06
# Train Loss at step 3450: 	6.605777e-05
# Test Loss at step 3500: 	8.185815e-06
# Train Loss at step 3500: 	6.653356e-05
# Test Loss at step 3550: 	8.192052e-06
# Train Loss at step 3550: 	6.6774555e-05
# Test Loss at step 3600: 	8.068853e-06
# Train Loss at step 3600: 	6.558938e-05
# Test Loss at step 3650: 	8.1050475e-06
# Train Loss at step 3650: 	6.565286e-05
# Test Loss at step 3700: 	8.1349535e-06
# Train Loss at step 3700: 	6.632398e-05
# Test Loss at step 3750: 	8.164301e-06
# Train Loss at step 3750: 	6.5966204e-05
# Test Loss at step 3800: 	8.068012e-06
# Train Loss at step 3800: 	6.566511e-05
# Test Loss at step 3850: 	8.028174e-06
# Train Loss at step 3850: 	6.578128e-05
# Test Loss at step 3900: 	8.115092e-06
# Train Loss at step 3900: 	6.626718e-05
# Test Loss at step 3950: 	8.006652e-06
# Train Loss at step 3950: 	6.587498e-05
# Test Loss at step 4000: 	8.031103e-06
# Train Loss at step 4000: 	6.55297e-05
# Test Loss at step 4050: 	7.957888e-06
# Train Loss at step 4050: 	6.55342e-05
# Test Loss at step 4100: 	8.03383e-06
# Train Loss at step 4100: 	6.5678294e-05
# Test Loss at step 4150: 	8.10632e-06
# Train Loss at step 4150: 	6.519071e-05
# Test Loss at step 4200: 	7.988715e-06
# Train Loss at step 4200: 	6.488183e-05
# Test Loss at step 4250: 	8.008352e-06
# Train Loss at step 4250: 	6.678447e-05
# Test Loss at step 4300: 	7.97705e-06
# Train Loss at step 4300: 	6.509999e-05
# Test Loss at step 4350: 	8.196164e-06
# Train Loss at step 4350: 	6.668702e-05
# Test Loss at step 4400: 	8.036283e-06
# Train Loss at step 4400: 	6.682007e-05
# Test Loss at step 4450: 	7.988096e-06
# Train Loss at step 4450: 	6.4963504e-05
# Test Loss at step 4500: 	7.933168e-06
# Train Loss at step 4500: 	6.457343e-05
# Test Loss at step 4550: 	8.10544e-06
# Train Loss at step 4550: 	6.525862e-05
# Test Loss at step 4600: 	8.1193e-06
# Train Loss at step 4600: 	6.523788e-05
# Test Loss at step 4650: 	7.9955935e-06
# Train Loss at step 4650: 	6.4646294e-05
# Test Loss at step 4700: 	8.106491e-06
# Train Loss at step 4700: 	6.504175e-05
# Test Loss at step 4750: 	8.034183e-06
# Train Loss at step 4750: 	6.5207445e-05
# Test Loss at step 4800: 	7.991588e-06
# Train Loss at step 4800: 	6.4407315e-05
# Test Loss at step 4850: 	8.03795e-06
# Train Loss at step 4850: 	6.456706e-05
# Test Loss at step 4900: 	8.167618e-06
# Train Loss at step 4900: 	6.617272e-05
# Test Loss at step 4950: 	8.135728e-06
# Train Loss at step 4950: 	6.5832544e-05
# Test Loss at step 5000: 	7.898769e-06
# Train Loss at step 5000: 	6.447177e-05
# Test Loss at step 5050: 	8.076136e-06
# Train Loss at step 5050: 	6.682488e-05
# Test Loss at step 5100: 	8.133379e-06
# Train Loss at step 5100: 	6.511397e-05
# Test Loss at step 5150: 	8.071973e-06
# Train Loss at step 5150: 	6.527107e-05
# Test Loss at step 5200: 	8.0165555e-06
# Train Loss at step 5200: 	6.435925e-05
# Test Loss at step 5250: 	8.047332e-06
# Train Loss at step 5250: 	6.478889e-05
# Test Loss at step 5300: 	7.9533975e-06
# Train Loss at step 5300: 	6.4682485e-05
# Test Loss at step 5350: 	8.179009e-06
# Train Loss at step 5350: 	6.6239285e-05
# Test Loss at step 5400: 	7.977391e-06
# Train Loss at step 5400: 	6.514498e-05
# Test Loss at step 5450: 	8.006743e-06
# Train Loss at step 5450: 	6.448798e-05
# Test Loss at step 5500: 	7.952361e-06
# Train Loss at step 5500: 	6.4224594e-05
# Test Loss at step 5550: 	7.916796e-06
# Train Loss at step 5550: 	6.467618e-05
# Test Loss at step 5600: 	7.942709e-06
# Train Loss at step 5600: 	6.430499e-05
# Test Loss at step 5650: 	7.915103e-06
# Train Loss at step 5650: 	6.4397536e-05
# Test Loss at step 5700: 	7.9046695e-06
# Train Loss at step 5700: 	6.4251326e-05
# Test Loss at step 5750: 	8.055125e-06
# Train Loss at step 5750: 	6.4823544e-05
# Test Loss at step 5800: 	8.177987e-06
# Train Loss at step 5800: 	6.561689e-05
# Test Loss at step 5850: 	8.019649e-06
# Train Loss at step 5850: 	6.470219e-05
# Test Loss at step 5900: 	8.009582e-06
# Train Loss at step 5900: 	6.47033e-05
# Test Loss at step 5950: 	8.05258e-06
# Train Loss at step 5950: 	6.5592336e-05
# Test Loss at step 6000: 	7.941519e-06
# Train Loss at step 6000: 	6.451426e-05
# Test Loss at step 6050: 	8.022538e-06
# Train Loss at step 6050: 	6.5101354e-05
# Test Loss at step 6100: 	8.01344e-06
# Train Loss at step 6100: 	6.4606706e-05
# Test Loss at step 6150: 	7.982473e-06
# Train Loss at step 6150: 	6.5818516e-05
# Test Loss at step 6200: 	8.054734e-06
# Train Loss at step 6200: 	6.5450695e-05
# Test Loss at step 6250: 	7.98526e-06
# Train Loss at step 6250: 	6.419159e-05
# Test Loss at step 6300: 	8.109179e-06
# Train Loss at step 6300: 	6.534756e-05
# Test Loss at step 6350: 	7.96174e-06
# Train Loss at step 6350: 	6.5304586e-05
# Test Loss at step 6400: 	7.891479e-06
# Train Loss at step 6400: 	6.416096e-05
# Test Loss at step 6450: 	7.924223e-06
# Train Loss at step 6450: 	6.425123e-05
# Test Loss at step 6500: 	7.967335e-06
# Train Loss at step 6500: 	6.43206e-05
# Test Loss at step 6550: 	7.925115e-06
# Train Loss at step 6550: 	6.414314e-05
# Test Loss at step 6600: 	8.2409115e-06
# Train Loss at step 6600: 	6.563647e-05
# Test Loss at step 6650: 	8.047572e-06
# Train Loss at step 6650: 	6.4826614e-05
# Test Loss at step 6700: 	7.9676765e-06
# Train Loss at step 6700: 	6.443031e-05
# Test Loss at step 6750: 	8.059812e-06
# Train Loss at step 6750: 	6.443028e-05
# Test Loss at step 6800: 	8.034672e-06
# Train Loss at step 6800: 	6.497484e-05
# Test Loss at step 6850: 	7.994419e-06
# Train Loss at step 6850: 	6.430815e-05
# Test Loss at step 6900: 	7.95229e-06
# Train Loss at step 6900: 	6.47509e-05
# Test Loss at step 6950: 	8.057666e-06
# Train Loss at step 6950: 	6.489267e-05
# Test Loss at step 7000: 	7.94962e-06
# Train Loss at step 7000: 	6.4941894e-05
